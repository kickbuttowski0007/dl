# %%
# Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the csv file

credit=pd.read_csv('Credit_Card_L1Y5s13EN8.csv')
credit
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# ## Preprocessing

# %%
# Dropping rows with null values

credit=credit.dropna()
credit
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 4     C10005   817.714335           1.000000      16.00             16.00
# 5     C10006  1809.828751           1.000000    1333.28              0.00
# ...      ...          ...                ...        ...               ...
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
# Dropping the column CUST_ID

credit=credit.drop(['CUST_ID'],axis=1)
credit
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8943     5.871712           0.500000      20.90             20.90
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
# Dropping rows with tenure < 10

credit1=credit[credit['TENURE']>=10]
credit1
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8808   385.462843           0.900000     427.10             50.00
# 8809     5.721468           0.900000      83.43              0.00
# 8810    28.277795           1.000000     394.80             44.80
# 8812     8.549640           0.400000       0.00              0.00
# 8813  3335.053583           0.700000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
credit1['TENURE'].min(),credit1['TENURE'].max()
# Out:
# (10, 12)

# %%
# Choosing Tenure as target

y=credit1['TENURE']
y
# Out:
# 0       12
# 1       12
# 2       12
# 4       12
# 5       12
#         ..
# 8808    10
# 8809    10
# 8810    10
# 8812    10
# 8813    10
# Name: TENURE, Length: 7928, dtype: int64

# %%
x=credit1.drop(['TENURE'],axis=1)
x
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8808   385.462843           0.900000     427.10             50.00
# 8809     5.721468           0.900000      83.43              0.00
# 8810    28.277795           1.000000     394.80             44.80
# 8812     8.549640           0.400000       0.00              0.00
# 8813  3335.053583           0.700000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
# Normalizing the features

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(x)
x_scaled
# Out:
# array([[-0.75170645, -0.39902077, -0.4362104 , ..., -0.55799845,
#         -0.31029421, -0.53570846],
#        [ 0.73265687,  0.03961482, -0.47875364, ...,  0.74950251,
#          0.06872553,  0.22129017],
#        [ 0.40056907,  0.47825041, -0.13396168, ..., -0.41714637,
#         -0.11210561, -0.53570846],
#        ...,
#        [-0.75763296,  0.47825041, -0.30269421, ..., -0.50790538,
#         -0.30831968,  2.87078877],
#        [-0.76689537, -2.41674739, -0.47875364, ..., -0.57565007,
#         -0.33815602,  1.16754016],
#        [ 0.7949064 , -0.96924849, -0.47875364, ..., -0.31348252,
#          0.04217027, -0.53570846]])

# %%
x_scaled_df=pd.DataFrame(x_scaled,columns=x.columns)
x_scaled_df
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.751706          -0.399021  -0.436210         -0.363189
# 1     0.732657           0.039615  -0.478754         -0.363189
# 2     0.400569           0.478250  -0.133962          0.080179
# 3    -0.386991           0.478250  -0.471619         -0.354014
# 4     0.078810           0.478250   0.115817         -0.363189
# ...        ...                ...        ...               ...
# 7923 -0.589934          -0.004249  -0.288290         -0.334517
# 7924 -0.768223          -0.004249  -0.441548         -0.363189
# 7925 -0.757633           0.478250  -0.302694         -0.337499
# 7926 -0.766895          -2.416747  -0.478754         -0.363189
# 7927  0.794906          -0.969248  -0.478754         -0.363189
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.364138     -0.451875            -0.832511
# 1                  -0.464794      2.602284            -1.248189
# ...

# %%
# Dimension of the feature set

x_scaled_df.shape
# Out:
# (7928, 16)

# %% [markdown]
# ## Principle Component Analysis

# %%
# Construction of covariance matrix

cm=np.cov(x_scaled.T)
cm
# Out:
# array([[ 1.00012615,  0.30969098,  0.17404292,  0.15732644,  0.12219135,
#          0.48732994, -0.08364406,  0.05966449, -0.06442918,  0.4589853 ,
#          0.38148921,  0.14642654,  0.52751009,  0.3212618 ,  0.39598706,
#         -0.33464582],
#        [ 0.30969098,  1.00012615,  0.11864654,  0.09357796,  0.1084147 ,
#          0.09425745,  0.22396338,  0.18879302,  0.17664393,  0.19700549,
#          0.13634459,  0.17781352,  0.08019382,  0.03423844,  0.12920761,
#         -0.16228357],
#        [ 0.17404292,  0.11864654,  1.00012615,  0.91714016,  0.67888737,
#         -0.05187256,  0.39895508,  0.4960416 ,  0.32035112, -0.12145595,
#         -0.0692532 ,  0.68727641,  0.35815656,  0.61150181,  0.08911844,
#          0.18593614],
#        [ 0.15732644,  0.09357796,  0.91714016,  1.00012615,  0.32967884,
#         -0.03220978,  0.27235709,  0.52274894,  0.13371011, -0.08476032,
#         -0.04831578,  0.54450453,  0.320119  ,  0.57624128,  0.04474332,
#          0.14143466],
# ...

# %%
cm.shape
# Out:
# (16, 16)

# %%
# Finding the eigen values

eig_val,eig_vec=np.linalg.eig(cm)
eig_val
# Out:
# array([4.61871969e+00, 3.47009995e+00, 1.51439528e+00, 1.22182711e+00,
#        1.06729672e+00, 8.71256816e-01, 7.27786020e-01, 6.26182040e-01,
#        5.24854800e-01, 4.04057605e-01, 3.02889222e-01, 2.45526836e-01,
#        1.64445118e-01, 1.95743505e-01, 4.69268068e-02, 1.08997276e-05])

# %%
# Finding the eigen vector

eig_vec
# Out:
# array([[ 9.04574988e-02, -4.03313392e-01,  1.70843947e-01,
#          2.91686236e-01, -9.01790781e-02, -2.55159767e-01,
#         -1.66839943e-01, -1.98582851e-02,  5.47640599e-02,
#          1.54175696e-01, -4.85814235e-01, -5.32270327e-01,
#         -2.25003357e-01, -1.29126129e-01,  4.69627781e-03,
#          3.92619699e-05],
#        [ 1.04407952e-01, -1.31225400e-01,  4.57818417e-01,
#          1.82418674e-01,  4.51161387e-01,  8.16227200e-02,
#          7.17273541e-02, -6.78983713e-01, -5.62972675e-02,
#         -1.28305460e-01,  6.20941014e-02,  1.64605462e-01,
#         -4.06468247e-02,  1.81042695e-02,  8.35451530e-03,
#          3.59960160e-05],
#        [ 4.13695389e-01, -4.60096286e-02, -2.36438523e-01,
#          1.21649395e-01, -1.71414781e-02,  2.62468619e-01,
#         -1.59506009e-02, -9.36663421e-02,  6.52148034e-02,
#          1.95403820e-01,  8.44394356e-02, -1.09091878e-01,
#          4.92814123e-02,  2.30649656e-01, -1.02017564e-03,
#         -7.48819361e-01],
# ...

# %%
# Sorting and finding the explained variance ratio of each component

## Sorting
sorted_eig_val=[i for i in sorted(eig_val, reverse=True)]

## Calculating the total
tot=sum(sorted_eig_val)

## Calculating the ratio explained
exp_var=[(i/tot) for i in sorted_eig_val]
exp_var
# Out:
# [0.28863356898926606,
#  0.21685389063301036,
#  0.09463776607854929,
#  0.07635456222000858,
#  0.06669763123888597,
#  0.054446682504545305,
#  0.04548088878036207,
#  0.03913144104852884,
#  0.03279928732580389,
#  0.025250414912951206,
#  0.018928188593253206,
#  0.015343491640474268,
#  0.012232425906710144,
#  0.010276523499673763,
#  0.002932555480930274,
#  6.811470466925932e-07]

# %%
# Construction of projection matrix and choosing only 2 dimensions

## Projection matrix
eigen_pair=[(np.abs(eig_val[i]),eig_vec[:,i]) for i in range(len(eig_val))]

## Taking 2 dimensions
w=np.hstack((eigen_pair[0][1][:,np.newaxis],eigen_pair[1][1][:,np.newaxis]))
w
# Out:
# array([[ 0.0904575 , -0.40331339],
#        [ 0.10440795, -0.1312254 ],
#        [ 0.41369539, -0.04600963],
#        [ 0.34883283, -0.06545363],
#        [ 0.33703454,  0.01165474],
#        [-0.02494894, -0.43782172],
#        [ 0.32787105,  0.18249305],
#        [ 0.29667259,  0.02091565],
#        [ 0.27928472,  0.16736899],
#        [-0.09160431, -0.43746987],
#        [-0.05331631, -0.42026711],
#        [ 0.39133642,  0.01371841],
#        [ 0.20967893, -0.23731972],
#        [ 0.26543411, -0.26562372],
#        [ 0.05460269, -0.16890934],
#        [ 0.13630598,  0.19115543]])

# %%
w.shape
# Out:
# (16, 2)

# %%
# Transforming 16 dimensions to 2 dimensions

x_scaled.shape , w.shape
# Out:
# ((7928, 16), (16, 2))

# %%
# Dot product

pca_x=x_scaled.dot(w)
pca_x
# Out:
# array([[-1.77876016,  1.12111847],
#        [-1.2881824 , -2.4419719 ],
#        [ 0.82713933,  0.42696932],
#        ...,
#        [ 0.42847816,  2.37336345],
#        [-2.08509713,  1.30535315],
#        [-1.78322598, -2.11586877]])

# %%
pca_x.shape
# Out:
# (7928, 2)

# %%
# Visualising the ttransformed dataset

plt.figure(figsize=(12,12))
plt.scatter(pca_x[:,0],pca_x[:,1],c=y)
plt.show();

# %% [markdown]
# ### Comments:
#
# It can be seen that after feature reduction to 2 dimensions, there is no proper segregation between different tenure years.
#
# This could be because, the first 2 components explain only 50% of the total variance.
#
# If the dataset is manifold/roll type distributed, that also could be a reason for PCA to not work accurately.

# %% [markdown]
# ## Locally Linear Embedding

# %%
# Importing the model

from sklearn.manifold import LocallyLinearEmbedding

# %%
# Building the model with n_neighbors = 5

lle=LocallyLinearEmbedding(n_neighbors=5,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 10

lle=LocallyLinearEmbedding(n_neighbors=10,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 15

lle=LocallyLinearEmbedding(n_neighbors=15,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 20

lle=LocallyLinearEmbedding(n_neighbors=20,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 30

lle=LocallyLinearEmbedding(n_neighbors=30,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 50

lle=LocallyLinearEmbedding(n_neighbors=50,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 60

lle=LocallyLinearEmbedding(n_neighbors=60,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 40

lle=LocallyLinearEmbedding(n_neighbors=40,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 35

lle=LocallyLinearEmbedding(n_neighbors=35,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %%
# Building the model with n_neighbors = 25

lle=LocallyLinearEmbedding(n_neighbors=25,random_state=100)

# Transforming the dataset
lle_x=lle.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(lle_x[:,0],lle_x[:,1],c=y)
plt.show();

# %% [markdown]
# ### Inference on n_neighbours
#
# It can be seen that most of the datapoints are clearly visible at n_neighbours = 30.
#
# When visuvalized at 25,35,40 and 50, the results were not as good as when n_neighbors = 30.

# %% [markdown]
# ### Comment on Performance
#
# The plot of n_neighbors = 30, also gives the better segregation of different Tenure years.
#
# It is definitely better than PCA in terms of retaining the maximum variance.

# %% [markdown]
# ## t-distributed Stochastic Neighbour Embedding (tSNE)

# %%
# Importing the model
from sklearn.manifold import TSNE

# %%
# Building the model with perplexity = 10

tsne=TSNE(n_components=2,perplexity=10)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 20

tsne=TSNE(n_components=2,perplexity=20)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 30

tsne=TSNE(n_components=2,perplexity=30)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 40

tsne=TSNE(n_components=2,perplexity=40)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 50

tsne=TSNE(n_components=2,perplexity=50)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 60

tsne=TSNE(n_components=2,perplexity=60)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 100

tsne=TSNE(n_components=2,perplexity=100)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 200

tsne=TSNE(n_components=2,perplexity=200)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
# Building the model with perplexity = 1000

tsne=TSNE(n_components=2,perplexity=1000)

# Transforming the dataset
tsne_x=tsne.fit_transform(x_scaled)

# Visualizing the transformed data
plt.figure(figsize=(12,12))
plt.scatter(tsne_x[:,0],tsne_x[:,1],c=y)
plt.show();
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ### Inference on Perplexity
#
# It can be seen that at a perplexity value of 30, the overlapping of the different tenure years datapoints are very less.
#
# Also, when the perplexity was increased beyond 30 to 50,100,200 and 1000, it was observed that the segregation of different tenure years was not better than perplexity of 30.

# %% [markdown]
# ### Comments on the model
#
# The plot of perplexity = 30, gives a better segregation between different tenure years.
#
# This is definitely better than than LLE model, as we can see the spread of the transformed data is good.

# %% [markdown]
# ## Most effective technique

# %% [markdown]
# The most effective technique would be TSNE, reason being the plot has good spread and the segregation of different tenure years can be better seen in the TSNE model as compared to other techniques

# %% [markdown]
# ## Least effective technique

# %% [markdown]
# The least effective technique would be PCA, as we can see the spread of the plot is very less and also there is no clear segregation between different tenure years because heavy overlapping.
#
# The Reason why PCA is not efective here is beacuse, the model is of manifold distribution. This itself limits the PCA technique.

# %% [markdown]
# ## Methods to improve efficiency
#
# In order to improve the efficiency of the model, the best way would be to increase the number of components.
#
# Reason being, increasing the number of components, allows the model to explain more amount of variance, giving it a better way to segregate.
